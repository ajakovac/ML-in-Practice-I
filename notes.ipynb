# %%
pages = {
    "Lecture 1": 27,
    "Lecture 2": 54,
    "Lecture 3": 84,
    "Lecture 4": 110,
    "Lecture 5": 130,
    "Lecture 6": 153,
    "Lecture 7": 174,
    "Lecture 8": 197,
    "Lecture 9": 220,
    "Lecture 10": 246,
    "Lecture 11": 268,
    "Lecture 12": 277,
}
v0=0
for k, v in pages.items():
    print(f'{k}: {v0+1}-{v} -> {v-v0} pages')
    v0=v
# Out:
# Lecture 1: 1-27 -> 27 pages
# Lecture 2: 28-54 -> 27 pages
# Lecture 3: 55-84 -> 30 pages
# Lecture 4: 85-110 -> 26 pages
# Lecture 5: 111-130 -> 20 pages
# Lecture 6: 131-153 -> 23 pages
# Lecture 7: 154-174 -> 21 pages
# Lecture 8: 175-197 -> 23 pages
# Lecture 9: 198-220 -> 23 pages
# Lecture 10: 221-246 -> 26 pages
# Lecture 11: 247-268 -> 22 pages
# Lecture 12: 269-277 -> 9 pages

# %%
84+27
# Out:
# 111
